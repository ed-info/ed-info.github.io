# %%
import qrcode
img = qrcode.make('Mon premier QR code !')
img

# %%
code = qrcode.make('https://basthon.fr/', format='svg')

code

# %%
code.download()

# %%
for page in ['index', 'about', 'galerie']:
    qrcode.make(f'https://basthon.fr/{page}.html', format='svg').show()
