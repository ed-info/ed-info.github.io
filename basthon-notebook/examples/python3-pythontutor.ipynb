# %%
from tutor import tutor

def syracuse(N):
    u, s = N, [N]
    while u != 1 :
        if u%2 == 0:
            u = u//2
        else:
            u = 3*u + 1
        s.append(u)
    return s

vol = syracuse(15)

tutor()
