# %% [markdown]
# # Utilisation de Markdown dans Basthon-Notebook

# %% [markdown]
# ## Un titre de second niveau

# %% [markdown]
# La syntaxe markdown est utilisable dans des cellules de type _Markdown_ :
#
#  - [un exemple de lien](https://basthon.fr)
#  - un équation : $e^{i \pi} + 1 = 0$
#  - un tableau :
#
# | Syntax      | Description |
# | ----------- | ----------- |
# | Header      | Title       |
# | Paragraph   | Text        |
