# %% [markdown]
# # Des easter eggs (fonctionalités cachées) de Python

# %% [markdown]
# ## Le plus simple 'hello world' du monde !

# %%
import __hello__

# %% [markdown]
# ## L'esprit de Python

# %%
import this

# %% [markdown]
# Voir le code de [this.py](https://github.com/python/cpython/blob/master/Lib/this.py) pour un autre easter egg.

# %%
import antigravity

# une redirection vers xkcd !

# %%
from __future__ import braces

# %%
from math import pi

hash(float("infinity")), round(pi, 5)
