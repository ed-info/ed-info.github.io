# %%
import requests
from io import StringIO

# données INSEE : https://www.insee.fr/fr/statistiques/4767258
response = requests.get("https://data.infobrisson.fr/classement_prenoms_filles_2019.csv")

# %%
import pandas as pd

df = pd.read_csv(StringIO(response.decode()), sep=';')

df

# %%
response = requests.get("https://data.infobrisson.fr/classement_prenoms_garcons_2019.csv")

df = pd.read_csv(StringIO(response.decode()), sep=';')

df
