# %%
from lolviz import *

# %%
ma_liste = ['hi', 'mom', {3, 4}, {"parrt":"user"}]

listviz(ma_liste)

# %%
mon_dico = {ord(c): c for c in 'abcdef'}

objviz(mon_dico)

# %%
objviz([ma_liste, mon_dico])
