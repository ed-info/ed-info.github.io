# %% [markdown]
# # Import d'un module depuis Pypi

# %%
import micropip

await micropip.install("emoji")
# Out:
# [object Promise]

# %%
from emoji import emojize
emojize(":thumbs_up:")
# Out:
# '👍'

# %%
emojize(":snake:")
# Out:
# '🐍'

# %%
print(emojize("J':red_heart: Basthon !"))
# Out:
# J'❤ Basthon !
