# %% [markdown]
# <div style="margin-left: auto; margin-right: auto; background-color: rgb(0,161,153); color: white; padding: 10px;">
#  <span><strong>Приклад блокноту, взято з курсу SNT/Програмування на Python</strong></span>
#  <h1 style="font-size:3em;padding-bottom:30px; text-align:center">Функції</h1>
# </div>

# %% [markdown]
# # 🟥 1. Вступ
#  ---
#
# <div class="alert" style="color:black; background-color:rgb(255, 214, 220); border-left: 8px solid rgb(255, 50, 80);">
#
# У мові програмування ми використовуємо те, що ми називаємо **функціями**. Функція — це пойменований набір інструкцій, які можуть отримувати вхідні **параметри** (які є *значеннями* або *змінними*) та можуть **повертати вміст однієї чи кількох змінних**.
#
# </div>

# %% [markdown]
# <blockquote class="alert alert-info" style="background-color:rgb(220,240,255); margin:10px 10%; ">
#
# <span style="font-size:1.5em">❔</span> **Чому ми використовуємо слово _функція_?**
#
# За аналогією ми використовуємо той самий термін як і в математиці, оскільки принцип ідентичний, оскільки математична функція також отримує параметри та повертає значення.
#
# </blockquote>

# %% [markdown]
# ## Перший приклад
#
# **Приклад 1** : Розглянемо математичну функцію $f$, визначену як $f(x) = 2x +1$. Вона отримує параметр (тут $x$) і повертає значення (тут $2x+1$). Цю математичну функція $f$ буде записано як функцію Python.
#
# ```python
# def f(x):
#     return 2 * x + 1
# ```
#
# Функції (в програмуванні) використовуються не лише для математичних обчислень, це далеко не так, вони використовуються всюди і постійно.

# %% [markdown]
# ## Синтаксис функції Python
#
# <div class="alert" style="color:black; background-color:rgb(255, 214, 220); border-left: 8px solid rgb(255, 50, 80);">
#
# Функція у Python має такий синтаксис:
#
# ```python
# def function_name(параметр1, параметр2 тощо):
#      інструкція1
#      інструкція2
#      ...
#      return повернуте_значення_1, повернуте_значення_2 тощо
# ```
#
# </div>
#
# **Аналіз**:
#
# - Ключове слово `def` повідомляє, що ми збираємося написати функцію;
# - Ми починаємо з написання **назви** нашої функції;
# - Потім у дужках ми пишемо її **параметри**, розділені комами ( можливо, функція не має параметрів, у такому випадку ми все одно пишемо круглі дужки, але нічого між ними);
# - Ми закінчуємо рядок двокрапкою (`:`);
# - Ми **зробимо відступ** і запишемо усі **інструкції**, які має виконати функція: усі рядки з відступами відповідають _блоку інструкцій_;
# - Нарешті, блок інструкцій зазвичай закінчується ключовим словом `return`, яке дозволяє вам **повернути** вміст однієї чи кількох змінних (розділених комами, якщо їх декілька)
#
# Щоб прояснити ідеї, розглянемо конкретний приклад.

# %% [markdown]
# ## Другий приклад
#
# **Приклад 2**
#
# <img src="https://raw.githubusercontent.com/germainbecker/SNT/master/Capytale/Python/les-fonctions/farine.png" alt="vente en ligne" width="300">
#
# У рядку сайту онлайн-продажів можна змінити кількість продукту, який ви бажаєте покупка (часто з кнопками "+" і "-"). Візьмемо для прикладу пачку органічного борошна вартістю 1,15 євро. Кожного разу, коли ви натискаєте одну з кнопок "+" або "-", функція відповідає за розрахунок ціни, яка відображатиметься на екрані _на основі_ кількості, вибраної покупцем. Цю функцію можна визначити в Python таким чином.
#
# ```python
# def price_to_display(quantity):
#      price = 1,15 * quantity
#      return price
# ```

# %% [markdown]
# <h2 style="background-color: rgb(0,161,153); color: white; border-radius: 3px;padding: 10px;">✏️ Вправа 1 : Розширюємо словниковий запас</h2>
#
# ✍️ **Завдання**: Перегляньте код цієї функції, щоб визначити:
#
# - її назву
# - кількість параметрів та їхні назви
# - її блок інструкцій
# - кількість повернених значень та їх імена
#
# ```python
# def price_to_display(quantity):
#  price = 1.15 * quantity
#  return price
# ```
#
#  > <span style="font-size:1.5em">🆘</span> Не соромтеся перечитати параграф [Синтаксис функції Python](#Syntax-of-a-Python-function ), щоб відповісти.
# </div>

# %% [raw]
# Ваша відповідь (необхідно заповнити):
#
# - назва:
# - кількість параметри та їх імена:
# - блок інструкцій:
# - кількість повернених значень та їх імена:

# %% [markdown]
# # 🟥 2. Напишіть і викличте функцію
# ---
#
# Коли функція написана, ви можете виконати її код, але на екрані можливо нічого не відбудеться, запис коду функції просто дозволить комп'ютеру її запам’ятати, інакше кажуть, записати в пам’ять.
#
# Щоб використовувати функцію та виконувати її блок інструкцій, ви повинні **викликати її**, щоб дізнатися значення, яке вона повертає, і це буде те, що ми пропонуємо вам виконати у наступній вправі.

# %% [markdown]
# <h2 style="background-color: rgb(0,161,153); color: white; border-radius: 3px;padding: 10px;">✏️ Вправа 2: Запис і виклик функції</h2>
#
# **Почніть із запуску наступного блоку та подивіться відео, у якому пояснюється, як написати та викликати функцію як у блокноті, так і в редакторі коду.**

# %%
from IPython.display import HTML
HTML("""<iframe width="560" height="315" src="https://www.youtube-nocookie.com/embed/WzF7PqUCzm8" title="YouTube video player" frameborder="0" allow="accelerometer; autoplay; clipboard-write; encrypted-media; gyroscope; picture-in-picture" allowfullscreen></iframe>""")
# Out:
# <iframe width="560" height="315" src="https://www.youtube-nocookie.com/embed/WzF7PqUCzm8" title="YouTube video player" frameborder="0" allow="accelerometer; autoplay; clipboard-write; encrypted-media; gyroscope; picture-in-picture" allowfullscreen></iframe>

# %% [markdown]
# 🐍  **Завдання 1 (у блокноті)**: Скопіюйте в клітинку нижче весь код функції `price_to_display`, який ми згадуємо нижче ( без копіювання та вставки, це для навчання). *Не забувайте про двокрапку в кінці першого рядка та дотримуйтеся відступів!*
#
# ```python
# def price_to_display(quantity):
#      price = 1,15 * quantity
#      return price
#  ```

# %% [markdown]
# Як показано у відео, у редакторі коду це трохи інакше: ви пишете код функції в області редагування (ліворуч у Basthon) і викликаєте його в консолі (праворуч у Basthon).
#
#  🐍 **Завдання 3 ( у редакторі коду)**: запустіть редактор Basthon, натиснувши це посилання [https://console.basthon.fr/](https://console.basthon.fr/), а потім скопіюйте код для  функції `price_to_display` в ліву область.
#
# 🐍 **Завдання 4 (у редакторі коду)**: виконайте код для цієї функції в редакторі Basthon, а потім викличте функцію в консолі (праворуч), щоб дізнатися, яка загальна ціна відображається, якщо вибрати 5 пакетів борошна, а якщо вибрати 2.

# %% [markdown]
#  <h2 style="background-color: rgb(0,161,153); color: white; border-radius: 3px;padding: 10px;">✏️ Вправа 3: Роздільність зображення</h2>
#
# <img src="https://cdn.pixabay.com/photo/2016/11/21/22/57/heart-1847868_960_720.png" alt="illustration" width="400">
#
# <p style="text-align:center">Джерело: <a href="https://pixabay.com/fr/vectors/c%c5%93ur-pixels-carr%c3%a9-amour-rouge-1847868/">Pixabay</a></p>

# %% [markdown]
# Цифрове зображення складається з **пікселів**. Загальна кількість пікселів, що утворюють зображення, називається **роздільністю зображення**.
# Наприклад, зображення шириною 800 пікселів і висотою 600 пікселів має роздільність, що дорівнює 800 x 600 = 480 000 пікселів.
#
# ✍️ **Завдання 1**: вручну обчисліть роздільність зображення за зображенням ілюстрації, поданої вище (будемо вважати, що кожен кольоровий квадрат відповідає 1 пікселю).

# %%
# тут запишіть відповідь!

# %% [markdown]
# 🐍 **Завдання 2**: Нам потрібно написати функцію під назвою `definition_image`, яка має два відповідні параметри `L` і `H` для числа пікселів по ширині та висоті зображення. Ця функція має обчислити та повернути роздільність цього зображення.
# Напишіть цю функцію нижче (замінюйте місця,позначені точками).

# %%
def definition_image(L,...):
    d =... *...
    return...

# %% [markdown]
# 🐍 **Завдання 3**: Викличте цю функцію, щоб дізнатися визначення зображення розміром 800\*600 пікселів.

# %%
# запишіть виклик функції та натисніть "Виконати"!

# %% [markdown]
# 🐍 **Завдання 4**: Викличте цю функцію, щоб дізнатися роздільність зображення на ілюстрації вище. Порівняйте отримане значення з відповіддю у завданні 1.

# %%
# запишіть виклик функції та натисніть "Виконати"!

# %% [markdown]
# 🐍 **Запитання 5**: запустіть редактор Basthon ([https://console. basthon.fr/](https://console.basthon.fr/)), потім скопіюйте, виконайте та викличте цю функцію, щоб знайти результати у запитаннях 3 і 4.

# %% [markdown]
# <h2 style="background-color: rgb(0,161,153); color: white; border-radius: 3px;padding: 10px;">✏️ Вправа 4: малювання черепахою</h2>
#
# <img src="https://upload.wikimedia.org/wikipedia/commons/3/3d/Turtle-animation.gif?20181216174412" alt="illustration">
#
# <p style="text-align:center">Кредит: <a href="https://commons.wikimedia.org/wiki/File:Turtle-animation.gif">Кормуліон</a>, <a href="https://creativecommons.org/licenses/by-sa/4.0">CC BY-SA 4.0</a>, через Wikimedia Commons.</p>
#
# У Scratch є кілька основних *блоків*, щоб рухатися вперед або обертатись:
#
# ![illustration](https://raw.githubusercontent.com/germainbecker/SNT/master/Capytale/Python/les-fonctions/scratch_avancer.png)
# ![illustration](https://raw.githubusercontent.com/germainbecker/SNT/master/Capytale/Python/les-fonctions/scratch_tourner_droite.png)
# ![illustration](https://raw.githubusercontent.com/germainbecker/SNT/master/Capytale/Python/les-fonctions/scratch_tourner_gauche.png)
#
# Це дозволено, серед іншого, щоб намалювати кота (або ельфа).
#
# У Python ви можете використовувати модуль `turtle` (= черепаха французькою) для малювання. У цьому модулі еквівалентами попередніх базових блоків є **функції** `forward`, `right` і `left`, які дозволяють рухати черепаху вперед або повертати:
#
# * `forward(x ) ` для переміщення на `x` пікселів
# * `right(a)` для повороту на `на` градусів праворуч
# * `left(a)` для обертання на `то` градусів ліворуч
#  n
# Для малювання ми викликаємо ці функції одну за одною з потрібними параметрами (це еквівалентно вкладенню блоків один за одним за допомогою Scratch)
#
# Наприклад:
#  ```python
# forward(100)
# right(90)
# forward(50)
# left(45)
# forward(200)
# ```
#
# Щоб використовувати ці функції, ви повинні повідомити Python у першому рядку, що ми хочемо завантажити модуль `turtle`. Це робиться за допомогою інструкції
#
# ```python
# from turtle import *
# ```

# %% [markdown]
# * * Дотримуйтесь інструкцій нижче, щоб побачити перший малюнок!**

# %%
from turtle import * # for load the module turtle

forward(100)
right(90)
forward(50)
left(45)
forward(200)

done() # для запиту відображення графіка

# %% [markdown]
# <blockquote class="alert alert-danger" style="margin: 10px 10% ; border-left: 10px solid #a94442;">
#
# <span style="font-size:1.5em">⚠️</span> Остання вказівка - <code>done() </code >, дозволяє виведення графіки. Якщо ви її не буде - нічого не станеться, зображення не буде побудовано.
#
# </blockquote>

# %% [markdown]
# ✍️ **Питання 1**: Скільки параметри, які мають функції `forward`, `right` і `left`? Поясніть.

# %% [raw]
# Ваша відповідь:

# %%
from turtle import *

forward (...)
...
...
...
...
...
...
...

done()

# %% [markdown]
# 🐍 **Запитання 3**: Напишіть інструкції для малювання квадрата, 100 пікселів з кожного боку, потім запустіть їх.

# %%
# запишіть інструкції тут!

# %% [markdown]
# <blockquote class="alert alert-info" style=" background-color:rgb(220,240,255); margin:10px 10%; ">
#
# <span style="font-size:1.5em">🧐</span> Зазвичай ви повинні були написати майже ті самі інструкції в запитаннях 2 і 3. Це не обов’язково ефективно. Ви побачите, що краще визначити функцію, яка дозволяє вам малювати квадрат, а потім викликати її кожного разу, коли ви хочете намалювати квадрат.
#
# </blockquote>

# %% [markdown]
# 🐍 **Запитання 4**: ми хочемо написати функцію `square`, яка має параметр `size`, який відповідає розміру сторін намальований квадрат.
#
# *Приклади*: виклик `square(50)` має намалювати квадрат зі стороною 50 пікселів, виклик `square(80)` має намалювати квадрат зі стороною 80 пікселів.

# %%
def square(size):
 forward(...)
 right(...) 
... # для продовження

# %% [markdown]
# **Не забудьте виконати наведену вище завдання, щоб запам’ятати функцію `square`**.
#
# Тепер ми можемо викликати цю функцію, щоб намалювати три квадрати різного розміру в рядку:

# %%
square(80)
square(50)
square(150)

done()

# %% [markdown]
# **Ці інструкції мають створити малюнок нижче, якщо ні в цьому випадку, ви повинні виправити код ваша функція `square`.**
#
# ![trois carrés](https://raw.githubusercontent.com/germainbecker/SNT/master/Capytale/Python/les-fonctions/trois_carres.png)

# %% [markdown]
# 🐍 **Питання 5**: ми хочемо отримати малюнок нижче. Напишіть правильні інструкції. *Не забудьте закінчити символом ` done()`!*
#
# ![plusieurs carrés](https://raw.githubusercontent.com/germainbecker/SNT/master/Capytale/Python/les-fonctions/carres.png)

# %%
# тепер ваша черга!

# %% [markdown]
# <h2 style="background-color: rgb(0,161,153); color: white; border-radius: 3px;padding: 10px;">💪 Спробуйте!</h2>
#
# Створіть функцію `rectangle`, яка дозволить вам малювати прямокутник потрібної довжини та ширини, а потім використовуйте цю функцію для малювання тенісного корту, розміри якого ми подаємо нижче.
#
# <img src="https://raw.githubusercontent.com/germainbecker/SNT/master/Capytale/Python/les-fonctions/Tennis_court_metric.svg" alt="dimensions d'un court de tennis" width="250">

# %%
# вводьте код програми тут!

# %% [markdown]
# # 🟥 Підсумок
# ---
#
# - **Функція** дозволяє згрупувати декілька послідовних інструкцій програми під певним ім'ям.
# - Функція має **ім’я**, можливо, **параметри**, які використовуються в **блоці інструкцій** Функція **зазвичай повертає** одне або кілька значень.
# - Ми можемо **викликати** функцію для виконання вказівок, які вона містить, і знати значення, яке вона повертає. Ми називаємо це за назвою, вказуючи значення бажаних параметрів у дужках.
# - У Python:
#  - ми використовуємо ключове слово `def`, щоб оголосити, що ми збираємося написати функцію
#  - після чого ми пишемо назву функції, а потім її параметри, написані в дужках - не забудьте про `:` в кінці першого рядка
#  - блок інструкцій функції розміщуються на певному *відступі* від початку рядка
#  - в кінці викорристайте ключове слово `return`, яке дозволяє вам повернути одне або кілька значень
#
# ```python
# def function_name(parameter1, parameter2 тощо):
#     instruction1
#     instruction2
#     ...
#     return value_returned_1, value_returned_2 тощо
# ` ``
#
# - Однією з переваг функції є можливість групувати інструкції, які, ймовірно, будуть використані кілька разів. Таким чином, це дає змогу полегшити код, оскільки тоді достатньо викликати функцію без необхідності щоразу копіювати всі її інструкції.
# - Існують інші причини, чому ми часто використовуємо функції в програмуванні, але ми не будемо їх обговорювати.

# %% [markdown]
# ---
# **Посилання**:
# - Роботи Александра Андре з  модулем «черепаха»: [Від нуля до Python: кіт і черепаха](https://capytale2.ac-paris.fr/basthon/notebook/?id=32146#) і [Черепаха: функції, фризи, феєрверки](https: //capytale2.ac-paris.fr/basthon/notebook/?id=33841#) для ідей для завдання 4.
#
# ---
# Створено вчителями SNT у середній школі Еммануеля Муньє, Анжер
#
# ![ Ліцензія Creative Commons](https://i.creativecommons.org/l/by-sa/4.0/88x31.png)
